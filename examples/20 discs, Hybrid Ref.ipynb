# %% [markdown]
# ### Setup

# %%
# install if not yet done
using Pkg

# Pkg.add(url="https://github.com/mppmu/BoostFractor.jl.git")
# Pkg.add(url="https://github.com/bergermann/Dragoon.jl.git")
Pkg.update()

# %%
using Dragoon, Plots #, Dates

# %%
# reference reflectivities of optimized states. booster will attempt to recreate these

ref0 = [
      0.6037533702979441 - 0.7971711659699691im,
    -0.49152420239804373 - 0.8708639150045079im,
     -0.9446107215621984 - 0.3281929077687685im,
     -0.9846694945053195 + 0.1744304634822827im,
     -0.8136139156426136 + 0.5814055351238824im,
     -0.4751750303984411 + 0.8798912946982941im,
    0.007749561940184724 + 0.9999699716940137im,
      0.5325698378687111 + 0.8463860630896989im,
      0.9042152260421181 + 0.4270770714913185im,
      0.9965552817110883 - 0.08293111897068542im,
];

ref1 = [
  0.9240607675676515 - 0.38224559885263165im,
  0.7380980822551304 - 0.674693427395952im,
  0.462948064022487 - 0.8863854071552547im,
  0.14786245633322903 - 0.9890079342488161im,
  -0.15586000240126052 - 0.9877791553031501im,
  -0.41490614421034666 - 0.9098642159665684im,
  -0.617404400711767 - 0.7866459216074747im,
  -0.7658156811116661 - 0.6430601391498648im,
  -0.8687939779605591 - 0.49517373098685186im,
  -0.9360561794775265 - 0.3518505774642497im,
  -0.9761192037376331 - 0.21723558662114203im,
  -0.9956895298891584 - 0.09274890872183986im,
  -0.9997664170139217 + 0.02161276037728511im,
  -0.9919648735330898 + 0.12651359482877816im,
  -0.9748503346892108 + 0.2228605504711954im,
  -0.9502174864493367 + 0.3115874330679862im,
  -0.9193032370696224 + 0.393549943861387im,
  -0.8829429833546631 + 0.46948023189991367im,
  -0.8416837189379979 + 0.5399708485415708im,
  -0.7958656259972035 + 0.6054732903737947im,
  -0.7456820601606868 + 0.6663019324259252im,
  -0.6912243153190141 + 0.7226402603728616im,
  -0.6325172274726643 + 0.7745462910312649im,
  -0.5695479277801538 + 0.8219581242139662im,
  -0.5022919227600631 + 0.8646981116725166im,
  -0.4307376970992456 + 0.9024771666350553im,
  -0.35491058222663224 + 0.9349002506275896im,
  -0.2748980884521972 + 0.9614733698679944im,
  -0.19087567409544032 + 0.9816142200674294im,
  -0.10313357313905225 + 0.9946675153495173im,
  -0.012103106793501572 + 0.9999267547205412im,
  0.08161873838943179 + 0.9966636250730342im,
  0.1772493286384882 + 0.9841659796483582im,
  0.27380786206107666 + 0.9617844117439002im,
  0.3701142439384575 + 0.9289862466333114im,
  0.46480279904208954 + 0.8854142296138187im,
  0.5563540269667009 + 0.8309453632327204im,
  0.6431457015941184 + 0.7657438256499466im,
  0.7235225589439993 + 0.6903007364179202im,
  0.7958805407946918 + 0.6054536850861058im,
  0.8587587180131229 + 0.512380195008022im,
  0.9109293743169278 + 0.4125623286323685im,
  0.9514758477257652 + 0.307723432962967im,
  0.9798484268083656 + 0.1997424854185147im,
  0.9958914606454912 + 0.09055494803379414im,
  0.9998389086057622 - 0.017948728033846926im,
  0.992280221622198 - 0.12401597388001956im,
  0.9741024265108893 - 0.2261071928657065im,
  0.946416901645635 - 0.32294743888049116im,
  0.9104801519376988 - 0.41355276921755146im,
]
;

# %%
n = 20

initdist = findpeak1d(22.025e9,n)

freqs = genFreqs(22.025e9,50e6; n=50)
freqsplot = genFreqs(22.025e9,150e6; n=1000)

booster = AnalyticalBooster(initdist)

hist = initHist(booster,10000,freqs,ObjRef1dSquare(ref1))
;

# %% [markdown]
# ### Optimizer

# %%
trace = linesearch(booster,hist,freqs,booster.vmotor*1e-3,
                    ObjRef1dSquare(ref1),
                    SolverHybrid("inv",0,1e-9,2),
                    Derivator2(1e-5,1e-6,"double"),
                    StepNorm("unit"),
                    SearchExtendedSteps(2000),
                    UnstuckRandom(1e-6,0.1);
                    ϵgrad=0.,maxiter=Int(1e2),showtrace=true);
# Out:
# Gradient norm: 201000.0
# Iter: 1, timestamp: 21 seconds
# Iter finished. Steps: 1522, Objective value: 89.935
#
# Gradient norm: 57600.0
# Iter: 2, timestamp: 42 seconds
# Iter finished. Steps: 1943, Objective value: 86.726
#
# Gradient norm: 136000.0
# Iter: 3, timestamp: 1 minute, 2 seconds
# Iter finished. Steps: 2000, Objective value: 75.726
#
# Gradient norm: 263000.0
# Iter: 4, timestamp: 1 minute, 23 seconds
# Iter finished. Steps: 2000, Objective value: 72.884
#
# Gradient norm: 350000.0
# Iter: 5, timestamp: 1 minute, 44 seconds
# Iter finished. Steps: 2000, Objective value: 70.229
#
# Gradient norm: 468000.0
# Iter: 6, timestamp: 2 minutes, 6 seconds
# Iter finished. Steps: 891, Objective value: 51.545
#
# Gradient norm: 404000.0
# Iter: 7, timestamp: 2 minutes, 28 seconds
# Iter finished. Steps: 0, Objective value: 51.545
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 403000.0
# Iter: 8, timestamp: 2 minutes, 51 seconds
# Iter finished. Steps: 0, Objective value: 51.711
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 401000.0
# Iter: 9, timestamp: 3 minutes, 14 seconds
# Iter finished. Steps: 0, Objective value: 51.606
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 400000.0
# Iter: 10, timestamp: 3 minutes, 36 seconds
# Iter finished. Steps: 816, Objective value: 51.341
#
# Gradient norm: 385000.0
# Iter: 11, timestamp: 3 minutes, 58 seconds
# Iter finished. Steps: 654, Objective value: 50.353
#
# Gradient norm: 344000.0
# Iter: 12, timestamp: 4 minutes, 20 seconds
# Iter finished. Steps: 774, Objective value: 47.786
#
# Gradient norm: 340000.0
# Iter: 13, timestamp: 4 minutes, 42 seconds
# Iter finished. Steps: 890, Objective value: 43.685
#
# Gradient norm: 398000.0
# Iter: 14, timestamp: 5 minutes, 4 seconds
# Iter finished. Steps: 0, Objective value: 43.685
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 403000.0
# Iter: 15, timestamp: 5 minutes, 27 seconds
# Iter finished. Steps: 0, Objective value: 44.226
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 404000.0
# Iter: 16, timestamp: 5 minutes, 50 seconds
# Iter finished. Steps: 0, Objective value: 44.222
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 407000.0
# Iter: 17, timestamp: 6 minutes, 11 seconds
# Iter finished. Steps: 707, Objective value: 42.889
#
# Gradient norm: 471000.0
# Iter: 18, timestamp: 6 minutes, 34 seconds
# Iter finished. Steps: 0, Objective value: 42.889
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 465000.0
# Iter: 19, timestamp: 6 minutes, 57 seconds
# Iter finished. Steps: 0, Objective value: 42.176
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 466000.0
# Iter: 20, timestamp: 7 minutes, 19 seconds
# Iter finished. Steps: 0, Objective value: 42.094
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 472000.0
# Iter: 21, timestamp: 7 minutes, 42 seconds
# Iter finished. Steps: 0, Objective value: 42.354
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 466000.0
# Iter: 22, timestamp: 8 minutes, 5 seconds
# Iter finished. Steps: 0, Objective value: 42.304
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 460000.0
# Iter: 23, timestamp: 8 minutes, 26 seconds
# Iter finished. Steps: 1254, Objective value: 29.062
#
# Gradient norm: 646000.0
# Iter: 24, timestamp: 8 minutes, 47 seconds
# Iter finished. Steps: 2000, Objective value: 4.259
#
# Gradient norm: 170000.0
# Iter: 25, timestamp: 9 minutes, 9 seconds
# Iter finished. Steps: 485, Objective value: 3.848
#
# Gradient norm: 161000.0
# Iter: 26, timestamp: 9 minutes, 31 seconds
# Iter finished. Steps: 422, Objective value: 3.647
#
# Gradient norm: 176000.0
# Iter: 27, timestamp: 9 minutes, 52 seconds
# Iter finished. Steps: 1181, Objective value: 2.057
#
# Gradient norm: 172000.0
# Iter: 28, timestamp: 10 minutes, 14 seconds
# Iter finished. Steps: 1163, Objective value: 0.671
#
# Gradient norm: 66600.0
# Iter: 29, timestamp: 10 minutes, 35 seconds
# Iter finished. Steps: 0, Objective value: 0.671
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 73700.0
# Iter: 30, timestamp: 10 minutes, 57 seconds
# Iter finished. Steps: 165, Objective value: 0.697
#
# Gradient norm: 79200.0
# Iter: 31, timestamp: 11 minutes, 20 seconds
# Iter finished. Steps: 19, Objective value: 0.623
#
# Gradient norm: 23900.0
# Iter: 32, timestamp: 11 minutes, 41 seconds
# Iter finished. Steps: 541, Objective value: 0.594
#
# Gradient norm: 33800.0
# Iter: 33, timestamp: 12 minutes, 3 seconds
# Iter finished. Steps: 0, Objective value: 0.594
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 26900.0
# Iter: 34, timestamp: 12 minutes, 25 seconds
# Iter finished. Steps: 0, Objective value: 0.595
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 72200.0
# Iter: 35, timestamp: 12 minutes, 47 seconds
# Iter finished. Steps: 190, Objective value: 0.634
#
# Gradient norm: 78500.0
# Iter: 36, timestamp: 13 minutes, 9 seconds
# Iter finished. Steps: 436, Objective value: 0.591
#
# Gradient norm: 98300.0
# Iter: 37, timestamp: 13 minutes, 30 seconds
# Iter finished. Steps: 604, Objective value: 0.46
#
# Gradient norm: 117000.0
# Iter: 38, timestamp: 13 minutes, 52 seconds
# Iter finished. Steps: 559, Objective value: 0.309
#
# Gradient norm: 113000.0
# Iter: 39, timestamp: 14 minutes, 13 seconds
# Iter finished. Steps: 419, Objective value: 0.213
#
# Gradient norm: 103000.0
# Iter: 40, timestamp: 14 minutes, 35 seconds
# Iter finished. Steps: 0, Objective value: 0.213
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 116000.0
# Iter: 41, timestamp: 14 minutes, 57 seconds
# Iter finished. Steps: 294, Objective value: 0.187
#
# Gradient norm: 105000.0
# Iter: 42, timestamp: 15 minutes, 19 seconds
# Iter finished. Steps: 164, Objective value: 0.171
#
# Gradient norm: 99600.0
# Iter: 43, timestamp: 15 minutes, 41 seconds
# Iter finished. Steps: 0, Objective value: 0.171
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 68900.0
# Iter: 44, timestamp: 16 minutes, 3 seconds
# Iter finished. Steps: 0, Objective value: 0.129
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 125000.0
# Iter: 45, timestamp: 16 minutes, 25 seconds
# Iter finished. Steps: 333, Objective value: 0.144
#
# Gradient norm: 88900.0
# Iter: 46, timestamp: 16 minutes, 48 seconds
# Iter finished. Steps: 0, Objective value: 0.144
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 12100.0
# Iter: 47, timestamp: 17 minutes, 10 seconds
# Iter finished. Steps: 0, Objective value: 0.09
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 33400.0
# Iter: 48, timestamp: 17 minutes, 33 seconds
# Iter finished. Steps: 0, Objective value: 0.098
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 21700.0
# Iter: 49, timestamp: 17 minutes, 55 seconds
# Iter finished. Steps: 0, Objective value: 0.1
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 33200.0
# Iter: 50, timestamp: 18 minutes, 17 seconds
# Iter finished. Steps: 0, Objective value: 0.119
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 38500.0
# Iter: 51, timestamp: 18 minutes, 39 seconds
# Iter finished. Steps: 0, Objective value: 0.134
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 40000.0
# Iter: 52, timestamp: 19 minutes, 1 second
# Iter finished. Steps: 0, Objective value: 0.143
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 42200.0
# Iter: 53, timestamp: 19 minutes, 24 seconds
# Iter finished. Steps: 0, Objective value: 0.154
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 58800.0
# Iter: 54, timestamp: 19 minutes, 46 seconds
# Iter finished. Steps: 0, Objective value: 0.164
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 55700.0
# Iter: 55, timestamp: 20 minutes, 9 seconds
# Iter finished. Steps: 0, Objective value: 0.161
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 71800.0
# Iter: 56, timestamp: 20 minutes, 31 seconds
# Iter finished. Steps: 0, Objective value: 0.148
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 99600.0
# Iter: 57, timestamp: 20 minutes, 54 seconds
# Iter finished. Steps: 0, Objective value: 0.184
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 183000.0
# Iter: 58, timestamp: 21 minutes, 16 seconds
# Iter finished. Steps: 349, Objective value: 0.213
#
# Gradient norm: 121000.0
# Iter: 59, timestamp: 21 minutes, 38 seconds
# Iter finished. Steps: 233, Objective value: 0.168
#
# Gradient norm: 125000.0
# Iter: 60, timestamp: 22 minutes
# Iter finished. Steps: 268, Objective value: 0.097
#
# Gradient norm: 63900.0
# Iter: 61, timestamp: 22 minutes, 22 seconds
# Iter finished. Steps: 0, Objective value: 0.097
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 62700.0
# Iter: 62, timestamp: 22 minutes, 43 seconds
# Iter finished. Steps: 0, Objective value: 0.096
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 51400.0
# Iter: 63, timestamp: 23 minutes, 5 seconds
# Iter finished. Steps: 0, Objective value: 0.077
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 18900.0
# Iter: 64, timestamp: 23 minutes, 27 seconds
# Iter finished. Steps: 122, Objective value: 0.061
#
# Gradient norm: 16600.0
# Iter: 65, timestamp: 23 minutes, 49 seconds
# Iter finished. Steps: 1, Objective value: 0.061
#
# Gradient norm: 16600.0
# Iter: 66, timestamp: 24 minutes, 12 seconds
# Iter finished. Steps: 11, Objective value: 0.061
#
# Gradient norm: 16700.0
# Iter: 67, timestamp: 24 minutes, 34 seconds
# Iter finished. Steps: 67, Objective value: 0.061
#
# Gradient norm: 16600.0
# Iter: 68, timestamp: 24 minutes, 56 seconds
# Iter finished. Steps: 0, Objective value: 0.061
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 62700.0
# Iter: 69, timestamp: 25 minutes, 19 seconds
# Iter finished. Steps: 0, Objective value: 0.096
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 24300.0
# Iter: 70, timestamp: 25 minutes, 41 seconds
# Iter finished. Steps: 0, Objective value: 0.073
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 57700.0
# Iter: 71, timestamp: 26 minutes, 3 seconds
# Iter finished. Steps: 0, Objective value: 0.084
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 101000.0
# Iter: 72, timestamp: 26 minutes, 26 seconds
# Iter finished. Steps: 0, Objective value: 0.138
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 116000.0
# Iter: 73, timestamp: 26 minutes, 48 seconds
# Iter finished. Steps: 373, Objective value: 0.065
#
# Gradient norm: 77700.0
# Iter: 74, timestamp: 27 minutes, 10 seconds
# Iter finished. Steps: 0, Objective value: 0.065
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 118000.0
# Iter: 75, timestamp: 27 minutes, 32 seconds
# Iter finished. Steps: 72, Objective value: 0.123
#
# Gradient norm: 117000.0
# Iter: 76, timestamp: 27 minutes, 54 seconds
# Iter finished. Steps: 49, Objective value: 0.121
#
# Gradient norm: 116000.0
# Iter: 77, timestamp: 28 minutes, 16 seconds
# Iter finished. Steps: 29, Objective value: 0.121
#
# Gradient norm: 116000.0
# Iter: 78, timestamp: 28 minutes, 38 seconds
# Iter finished. Steps: 16, Objective value: 0.121
#
# Gradient norm: 115000.0
# Iter: 79, timestamp: 29 minutes
# Iter finished. Steps: 8, Objective value: 0.12
#
# Gradient norm: 115000.0
# Iter: 80, timestamp: 29 minutes, 22 seconds
# Iter finished. Steps: 3, Objective value: 0.12
#
# Gradient norm: 115000.0
# Iter: 81, timestamp: 29 minutes, 44 seconds
# Iter finished. Steps: 2, Objective value: 0.12
#
# Gradient norm: 115000.0
# Iter: 82, timestamp: 30 minutes, 6 seconds
# Iter finished. Steps: 1, Objective value: 0.12
#
# Gradient norm: 115000.0
# Iter: 83, timestamp: 30 minutes, 28 seconds
# Iter finished. Steps: 0, Objective value: 0.12
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 69700.0
# Iter: 84, timestamp: 30 minutes, 51 seconds
# Iter finished. Steps: 0, Objective value: 0.055
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 30700.0
# Iter: 85, timestamp: 31 minutes, 13 seconds
# Iter finished. Steps: 0, Objective value: 0.025
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 56100.0
# Iter: 86, timestamp: 31 minutes, 36 seconds
# Iter finished. Steps: 0, Objective value: 0.045
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 37400.0
# Iter: 87, timestamp: 31 minutes, 58 seconds
# Iter finished. Steps: 0, Objective value: 0.051
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 43900.0
# Iter: 88, timestamp: 32 minutes, 20 seconds
# Iter finished. Steps: 0, Objective value: 0.05
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 36700.0
# Iter: 89, timestamp: 32 minutes, 43 seconds
# Iter finished. Steps: 0, Objective value: 0.038
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 93900.0
# Iter: 90, timestamp: 33 minutes, 5 seconds
# Iter finished. Steps: 0, Objective value: 0.094
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 96400.0
# Iter: 91, timestamp: 33 minutes, 28 seconds
# Iter finished. Steps: 0, Objective value: 0.106
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 150000.0
# Iter: 92, timestamp: 33 minutes, 50 seconds
# Iter finished. Steps: 258, Objective value: 0.1
#
# Gradient norm: 72000.0
# Iter: 93, timestamp: 34 minutes, 12 seconds
# Iter finished. Steps: 0, Objective value: 0.1
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 34000.0
# Iter: 94, timestamp: 34 minutes, 34 seconds
# Iter finished. Steps: 0, Objective value: 0.083
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 31500.0
# Iter: 95, timestamp: 34 minutes, 56 seconds
# Iter finished. Steps: 0, Objective value: 0.084
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 74600.0
# Iter: 96, timestamp: 35 minutes, 18 seconds
# Iter finished. Steps: 0, Objective value: 0.103
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 92900.0
# Iter: 97, timestamp: 35 minutes, 40 seconds
# Iter finished. Steps: 149, Objective value: 0.126
#
# Gradient norm: 84300.0
# Iter: 98, timestamp: 36 minutes, 3 seconds
# Iter finished. Steps: 0, Objective value: 0.126
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 80000.0
# Iter: 99, timestamp: 36 minutes, 25 seconds
# Iter finished. Steps: 0, Objective value: 0.126
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Gradient norm: 38600.0
# Iter: 100, timestamp: 36 minutes, 48 seconds
# Iter finished. Steps: 0, Objective value: 0.114
#
# Stuck. Trying to unstuck.
#
# Unstuck successfull.
# Terminated. Max iterations reached.
# Final objective value: 0.109
# Elapsed movement time:  36 minutes, 48 seconds
# Summed distance:   0.349
# Elapsed computing time: 3 minutes, 2 seconds, 993 milliseconds

# %%
#obtain result, booster is now in optimized position
pos2dist(booster.pos)     #in distance space
# booster.pos               #in position space

# %%
plot(reverse((x->x.objvalue).(hist[1:10000])))

# %%
plot(freqs,real(getRef1d(booster,freqs)))
plot!(freqs,imag(getRef1d(booster,freqs)))

# %%
plot(freqs,real(ref1))
plot!(freqs,imag(ref1))

# %%
analyse(hist,trace,freqsplot)

# %%
#get handy output
plt = analyse(hist,trace,freqsplot; freqs=freqs,div=10)

#savefig(plt[i],"cool_epic_result_wow.svg")
